# %% [markdown]
# <a href="https://colab.research.google.com/github/quangvu32/quangvu32/blob/Deep-learning/BT1_21522801.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
import pandas as pd

# %%
penguins = sns.load_dataset('penguins')

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
list(penguins)
# Out:
# ['species',
#  'island',
#  'bill_length_mm',
#  'bill_depth_mm',
#  'flipper_length_mm',
#  'body_mass_g',
#  'sex']

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 333 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            333 non-null    object
#  1   island             333 non-null    object
#  2   bill_length_mm     333 non-null    float64
#  3   bill_depth_mm      333 non-null    float64
#  4   flipper_length_mm  333 non-null    float64
#  5   body_mass_g        333 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 20.8+ KB

# %%
sns.jointplot(data=penguins, x='bill_length_mm', y='bill_depth_mm', hue='species')

# %%
sns.scatterplot(data=penguins, x='bill_length_mm', y='bill_depth_mm')

# %%
sns.displot(data=penguins, x='flipper_length_mm')

# %%
sns.displot(data = penguins, x= 'flipper_length_mm', hue = 'species')

# %%
sns.distplot(a = penguins['bill_length_mm'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(a = penguins['bill_depth_mm'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(a = penguins['flipper_length_mm'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.displot(data = penguins, x = 'flipper_length_mm', kind = 'kde', fill = True)

# %%
sns.displot(data = penguins, x = 'flipper_length_mm', hue = 'species', kind = 'kde', fill = True)

# %%
sns.displot(data=penguins, x= 'flipper_length_mm', y = 'body_mass_g')

# %%
sns.displot(data = penguins, x = 'flipper_length_mm', y = 'body_mass_g', binwidth = (0.5, 0.25))

# %%
sns.displot(data = penguins, x = 'flipper_length_mm', y = 'body_mass_g', binwidth = (0.5, 0.25), hue = 'species' )

# %%
sns.jointplot(data = penguins, x = 'flipper_length_mm' , y = 'body_mass_g' )

# %%
sns.jointplot(data = penguins, x = 'flipper_length_mm', y = 'body_mass_g', hue = 'species')

# %%
g = sns.jointplot(data = penguins, x = 'flipper_length_mm', y = 'body_mass_g', hue = 'species')
g.plot_joint(sns.kdeplot)
g.plot_marginals(sns.histplot)

# %%
sns.pairplot(penguins, vars = penguins.columns[0:4])

# %%
sns.pairplot(penguins,  hue = 'species')
plt.savefig('penguins.pdf')

# %%
g = sns.pairplot(penguins, hue = 'species')
g.map_diag(sns.histplot)
g.map_lower(sns.kdeplot)

# %%
y_sex_class = pd.crosstab(index=penguins['sex'], 
                             columns=penguins['species'],
                             margins=True,normalize='index')

y_sex_class
# Out:
# species    Adelie  Chinstrap    Gentoo
# sex
# Female   0.442424   0.206061  0.351515
# Male     0.434524   0.202381  0.363095
# All      0.438438   0.204204  0.357357

# %%
plt.pie(penguins['species'].value_counts(), labels = penguins['species'].unique())
plt.show()

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
from graphviz import Source
from sklearn.tree import export_graphviz

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
penguins.groupby(['island', 'species']).size().reset_index(name='counts')
# Out:
#       island    species  counts
# 0     Biscoe     Adelie      44
# 1     Biscoe     Gentoo     124
# 2      Dream     Adelie      56
# 3      Dream  Chinstrap      68
# 4  Torgersen     Adelie      52

# %%
penguins_full = penguins.dropna()

y = penguins_full.body_mass_g

features = ['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm']
X = penguins_full[features]

# %%
penguin_model = DecisionTreeRegressor(max_depth = 2, random_state=42)

model_fit = penguin_model.fit(X, y)

# %%
from sklearn.tree import export_graphviz

export_graphviz(model_fit, out_file='penguins_dt.dot',feature_names=features,rounded=True,filled=True)
Source.from_file('penguins_dt.dot')

# %%
penguin_model = DecisionTreeRegressor(max_depth = 4, random_state=42)

model_fit = penguin_model.fit(X, y)
export_graphviz(model_fit, out_file='penguins_dt.dot',feature_names=features,rounded=True,filled=True)
Source.from_file('penguins_dt.dot')

# %%
penguin_model = DecisionTreeRegressor(random_state=42)

model_fit = penguin_model.fit(X, y)
from sklearn.tree import export_graphviz

export_graphviz(model_fit, out_file='penguins_dt.dot',feature_names=features,rounded=True,filled=True)
Source.from_file('penguins_dt.dot')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, random_state = 985)

# %%
X_train
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm
# 263            49.6           15.0              216.0
# 145            39.0           18.7              185.0
# 91             41.1           18.1              205.0
# 158            46.1           18.2              178.0
# 181            52.8           20.0              205.0
# ..              ...            ...                ...
# 210            50.2           18.8              202.0
# 264            50.5           15.9              222.0
# 319            51.1           16.5              225.0
# 89             38.9           18.8              190.0
# 76             40.9           16.8              191.0
#
# [233 rows x 3 columns]

# %%
X_test
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm
# 249            50.0           15.3              220.0
# 223            50.0           15.2              218.0
# 61             41.3           21.1              195.0
# 68             35.9           16.6              190.0
# 200            51.5           18.7              187.0
# ..              ...            ...                ...
# 25             35.3           18.9              187.0
# 220            46.1           13.2              211.0
# 323            49.1           15.0              228.0
# 308            47.5           14.0              212.0
# 36             38.8           20.0              190.0
#
# [100 rows x 3 columns]

# %%
y_train
# Out:
# 263    4750.0
# 145    3650.0
# 91     4300.0
# 158    3250.0
# 181    4550.0
#         ...
# 210    3800.0
# 264    5550.0
# 319    5250.0
# 89     3600.0
# 76     3700.0
# Name: body_mass_g, Length: 233, dtype: float64

# %%
y_test
# Out:
# 249    5550.0
# 223    5700.0
# 61     4400.0
# 68     3050.0
# 200    3250.0
#         ...
# 25     3800.0
# 220    4500.0
# 323    5500.0
# 308    4875.0
# 36     3950.0
# Name: body_mass_g, Length: 100, dtype: float64

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report
cart = DecisionTreeClassifier()
cart_tuned = DecisionTreeClassifier(max_depth = 10, min_samples_split = 54).fit(X_train, y_train)
y_pred = cart_tuned.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.03

# %%
cart_tuned = DecisionTreeClassifier(max_depth = 20, min_samples_split = 54).fit(X_train, y_train)
y_pred = cart_tuned.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.03
